# %% [markdown]
# <a href="https://colab.research.google.com/github/count-im/PRactice/blob/master/eng1st.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('추가')
# Out:
# 추가

# %%
1+1
# Out:
# 2

# %%
2+2
